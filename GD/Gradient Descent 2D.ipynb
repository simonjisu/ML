# %%
from GD_xy import *

# %%
x0 = 3.
y0 = 2.

# %% [markdown]
# ## Stochastic Gradient Descent
# ---

# %%
point, history_, frame = sgd(x0, y0, n=10000, alpha=0.0001, epsilon=1e-6)
# Out:
# 177

# %%
point
# Out:
# (1.0002427173288106, 1.0002476689825603)

# %%
doani = AniPlot('SGD', frame, 50)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Momentum
# ---

# %%
point, history_, frame = momentum(x0, y0, n=10, gamma=1.1, alpha=0.0001, epsilon=1e-6)

# %%
point
# Out:
# (2.1636488804327065, 6.0970113633334631)

# %%
doani = AniPlot('Momentum', frame, 500)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Nesterov Accelerated Gradient (NAG)
# ---

# %%
point, history_, frame = NAG(x0, y0, n=10000, alpha=0.0001, epsilon=1e-6)
# Out:
# 92

# %%
point
# Out:
# (0.99998998279952689, 1.0000277865610054)

# %%
doani = AniPlot('NAG', frame, 50)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Adagrad
# ---

# %%
x0 = -1.
y0 = -2.

# %%
point, history_, frame = Adagrad(x0, y0, n=10000, alpha=0.1, epsilon=1e-6)

# %%
point
# Out:
# (0.40109980753617147, 0.15800908657240978)

# %%
doani = AniPlot('Adagrad', 2000, 15)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# 다른포인트와 비교

# %%
x0 = 3.
y0 = -2.

# %%
point, history_, frame = Adagrad(x0, y0, n=10000, alpha=0.1, epsilon=1e-6)
# Out:
# 2814

# %%
point
# Out:
# (0.91412458042469547, 0.83409474402375539)

# %%
doani = AniPlot('Adagrad', 2000, 15)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## RMSProp
# ---

# %%
point, history_, frame = RMSProp(x0, y0, n=10000, alpha=0.1, epsilon=1e-6)

# %%
point
# Out:
# (1.5942466893533811, 2.5433194202012337)

# %%
doani = AniPlot('RMSProp', 1000, 50)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# 다른포인트와 비교

# %%
x0 = 3.
y0 = 2.

# %%
point, history_, frame = Adagrad(x0, y0, n=10000, alpha=0.1, epsilon=1e-6)

# %%
point
# Out:
# (1.809276533715664, 3.2750941026962774)

# %%
doani = AniPlot('RMSProp', 2000, 15)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## AdaDelta
# ---

# %%
point, history_, frame = AdaDelta(x0, y0, n=30000, epsilon=1e-8)

# %%
point
# Out:
# (2.9489285547877584, 2.008799067922121)

# %%
doani = AniPlot('AdaDelta', 1000, 50)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Adam
# ---

# %%
point, history_, frame = Adam(x0, y0, n=10000, alpha=0.1, epsilon=1e-8)
# Out:
# 3020

# %%
point
# Out:
# (1.0009556815658873, 1.0019148486107121)

# %%
doani = AniPlot('Adam', 2000, 15)
doani.set_data(history_)
anim = doani.animate()
anim
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
